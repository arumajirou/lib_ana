# %% [markdown]
# # Cognitive Library Explorer V5
#
# このノートブックは `C:/lib_ana/src` 配下のモジュールを読み込み、V5 UI を表示します。
#
# - V4 従来 UI: `from ui_v4 import CognitiveLibraryUIV4`
# - V5 新 UI: `from v5.ui_v5 import CognitiveLibraryUIV5`

# %%
import os, sys
SRC_DIR = os.path.join(os.getcwd(), 'src')
if SRC_DIR not in sys.path:
    sys.path.append(SRC_DIR)

from v5.ui_v5 import CognitiveLibraryUIV5

ui = CognitiveLibraryUIV5()
ui.display()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       3 if SRC_DIR not in sys.path:
#       4     sys.path.append(SRC_DIR)
# ----> 6 from v5.ui_v5 import CognitiveLibraryUIV5
#       8 ui = CognitiveLibraryUIV5()
#       9 ui.display()
#
# ImportError: cannot import name 'CognitiveLibraryUIV5' from 'v5.ui_v5' (C:\lib_ana\src\CLE_lib_ana\src\v5\ui_v5.py)
