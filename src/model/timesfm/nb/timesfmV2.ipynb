# %% [markdown]
# # TimesFM 2.5 (PyTorch) による Loto データ予測の動作確認
#
# **目的**:
# ローカルの PostgreSQL データベース (`dataset.loto_y_ts`) からデータを取得し、`loto` (ロト種別) および `ts_type` (時系列タイプ) ごとに `y` (値) の将来予測を行います。
#
# **環境**:
# - Model: TimesFM 2.5 (200M parameters, PyTorch version)
# - Data Source: Local PostgreSQL (`dataset.loto_y_ts`)
# - Path: `/mnt/e/env/ts/lib_ana/src/model/timesfm/timesfmV2.ipynb`
#
# **前提条件**:
# - 必要なライブラリ (`torch`, `pandas`, `numpy`, `sqlalchemy`, `psycopg2-binary`, `timesfm` 等) がインストールされていること。
# - Hugging Face のモデル `google/timesfm-2.5-200m-pytorch` へのアクセスが可能であること。

# %%
import os
import sys
import numpy as np
import pandas as pd
import torch
from sqlalchemy import create_engine
from textwrap import dedent

# timesfm モジュールがパスに通っているか確認してください
# 必要であれば sys.path.append() で調整します
# sys.path.append("../../../") 

import timesfm

# ログ設定の抑制（任意）
import logging
logging.getLogger("transformers").setLevel(logging.ERROR)

print(f"Python: {sys.version}")
print(f"Torch: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
# Out:
# Python: 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0]
# Torch: 2.4.1+cu121
# CUDA Available: True

# %% [markdown]
# ## データベースからのデータ取得

# %%
# データベース接続情報の定義
DB_CONFIG = {
    "user": "loto",
    "password": "z",
    "host": "127.0.0.1",
    "port": "5432",
    "database": "loto"
}

# 接続文字列の作成 (PostgreSQL)
db_url = f"postgresql+psycopg2://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['database']}"

# エンジンの作成
engine = create_engine(db_url)

# データ取得クエリ
# loto, ts_type ごとに時系列順 (ds) にデータを取得します
query = """
SELECT
    loto,
    ts_type,
    ds,
    y
FROM
    dataset.loto_y_ts
ORDER BY
    loto,
    ts_type,
    ds ASC
"""

try:
    print("Fetching data from database...")
    df = pd.read_sql(query, engine)
    print(f"Data loaded successfully. Shape: {df.shape}")
    display(df.head())
except Exception as e:
    print(f"Error loading data: {e}")
# Out:
# Fetching data from database...
# Data loaded successfully. Shape: (456096, 4)
#      loto ts_type          ds     y
# 0  bingo5  cumsum  2017-04-05  10.0
# 1  bingo5  cumsum  2017-04-05  19.0
# 2  bingo5  cumsum  2017-04-05  13.0
# 3  bingo5  cumsum  2017-04-05  23.0
# 4  bingo5  cumsum  2017-04-05   1.0

# %%
# !pip list
# Out:
# Package                            Version                Build Editable project location
# ---------------------------------- ---------------------- ----- -------------------------------------------------
# absl-py                            2.4.0
# accelerate                         1.12.0
# accelerator                        2025.11.11
# adagio                             0.2.6
# ai4ts                              0.0.3
# aioboto3                           12.4.0
# aiobotocore                        2.12.3
# aiohappyeyeballs                   2.6.1
# aiohttp                            3.13.3
# aiohttp-cors                       0.8.1
# aioitertools                       0.13.0
# aiosignal                          1.4.0
# alabaster                          1.0.0
# alembic                            1.18.0
# altair                             6.0.0
# annotated-doc                      0.0.4
# annotated-types                    0.7.0
# antlr4-python3-runtime             4.9.3
# anyio                              4.12.1
# appdirs                            1.4.4
# apsw                               3.51.2.0
# apswutils                          0.1.2
# arch                               7.2.0
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               25.1.0
# arrow                              1.4.0
# arxiv                              2.4.0
# asttokens                          3.0.1
# astunparse                         1.6.3
# async-lru                          2.0.5
# attrs                              25.4.0
# autogluon                          1.5.0
# autogluon.common                   1.5.0
# autogluon.core                     1.5.0
# autogluon.features                 1.5.0
# autogluon.multimodal               1.5.0
# autogluon.tabular                  1.5.0
# autogluon.timeseries               1.5.0
# autots                             0.6.21
# axial_positional_embedding         0.2.1
# babel                              2.17.0
# backports.zstd                     1.3.0
# BasicTS                            1.1.0                        /mnt/e/env/ts/tslib/model/BasicTS
# beartype                           0.18.5
# beautifulsoup4                     4.14.3
# benchpots                          0.4
# black                              24.10.0
# bleach                             6.3.0
# blinker                            1.9.0
# blis                               1.3.3
# blosc2                             3.12.2
# boto3                              1.34.69
# botocore                           1.34.69
# bottle                             0.13.4
# Bottleneck                         1.4.2
# Brotli                             1.2.0
# cachetools                         6.2.6
# captum                             0.8.0
# catalogue                          2.0.10
# catboost                           1.2.8
# category_encoders                  2.7.0
# causal-learn                       0.1.4.4
# certifi                            2026.1.4
# cffi                               1.17.1
# charset-normalizer                 3.4.4
# chronos-forecasting                2.2.2                        /mnt/e/env/ts/tslib/model/chronos-forecasting
# clarabel                           0.11.1
# click                              8.3.1
# cloudpathlib                       0.23.0
# cloudpickle                        3.1.2
# cmdstanpy                          1.3.0
# codetiming                         1.4.0
# colorama                           0.4.6
# colorful                           0.5.8
# colorlog                           6.10.1
# CoLT5-attention                    0.11.1
# comm                               0.2.3
# confection                         0.1.5
# contourpy                          1.3.2
# coreforecast                       0.0.16
# coverage                           7.13.1
# cramjam                            2.11.0
# cryptography                       46.0.3
# cycler                             0.12.1
# cymem                              2.0.13
# Cython                             3.2.4
# dart                               1.0
# darts                              0.40.0
# dash                               3.3.0
# databricks-sdk                     0.77.0
# datasets                           2.17.1
# datasetsforecast                   1.0.0
# debugpy                            1.8.19
# decorator                          5.2.1
# deepspeed                          0.14.0
# defusedxml                         0.7.1
# Deprecated                         1.3.1
# deprecation                        2.1.0
# dill                               0.3.8
# distlib                            0.4.0
# docker                             7.1.0
# docker-pycreds                     0.4.0
# docutils                           0.22.4
# dtw-python                         1.5.3
# easy-torch                         1.3.3
# easydict                           1.13
# einops                             0.7.0
# einshape                           1.0
# einx                               0.3.0
# et_xmlfile                         2.0.0
# evaluate                           0.4.6
# executing                          2.2.1
# faim-sdk                           0.5.1
# fastai                             2.8.6
# fastapi                            0.128.0
# fastcore                           1.11.3
# fastdownload                       0.0.7
# fastjsonschema                     2.21.2
# fastlite                           0.2.3
# fastparquet                        2025.12.0
# fastprogress                       1.1.3
# fasttransform                      0.0.2
# feedparser                         6.0.12
# filelock                           3.20.3
# Flask                              3.1.2
# flask-cors                         6.0.2
# Flask-SQLAlchemy                   3.1.1
# flatbuffers                        25.12.19
# flood_forecast                     1.0.dev0
# fonttools                          4.61.1
# fqdn                               1.5.1
# frozendict                         2.4.7
# frozenlist                         1.8.0
# fsspec                             2023.10.0
# fugue                              0.9.4
# future                             1.0.0
# gast                               0.7.0
# gdown                              5.2.0
# git-filter-repo                    2.47.0
# gitdb                              4.0.12
# GitPython                          3.1.46
# gluonts                            0.14.4
# gmpy2                              2.2.1
# google-api-core                    2.29.0
# google-auth                        2.47.0
# google-cloud                       0.34.0
# google-cloud-core                  2.5.0
# google-cloud-storage               3.7.0
# google-crc32c                      1.8.0
# google-pasta                       0.2.0
# google-resumable-media             2.8.0
# googleapis-common-protos           1.72.0
# GPUtil                             1.4.0
# granite-tsfm                       0.3.3.dev33+gf13acb074       /mnt/e/env/ts/tslib/model/granite-tsfm
# graphene                           3.4.3
# graphql-core                       3.2.7
# graphql-relay                      3.2.0
# graphviz                           0.21
# greenlet                           3.3.0
# grpcio                             1.78.0
# gunicorn                           23.0.0
# h11                                0.16.0
# h2                                 4.3.0
# h5py                               3.15.1
# hf-xet                             1.2.0
# hierarchicalforecast               1.3.1
# hjson                              3.1.0
# holidays                           0.88
# hpack                              4.1.0
# httpcore                           1.0.9
# httptools                          0.7.1
# httpx                              0.28.1
# huey                               2.6.0
# huggingface-hub                    0.36.0
# hydra-core                         1.3.0
# hyper-connections                  0.3.16
# hyperframe                         6.1.0
# hyperopt                           0.2.7
# hypertools                         0.8.1
# hypothesis                         6.150.2
# idna                               3.11
# ImageIO                            2.37.2
# imagesize                          1.4.1
# imbalanced-learn                   0.14.1
# importlib_metadata                 8.7.0
# importlib_resources                6.5.2
# iniconfig                          2.3.0
# inquirerpy                         0.3.4
# intel-cmplr-lib-rt                 2025.3.1
# ipykernel                          7.1.0
# ipympl                             0.9.8
# ipython                            9.9.0
# ipython_pygments_lexers            1.1.1
# ipywidgets                         8.1.8
# isoduration                        20.11.0
# isort                              5.13.2
# itsdangerous                       2.2.0
# jax                                0.6.1
# jaxlib                             0.6.1
# jaxtyping                          0.2.29
# jedi                               0.19.2
# Jinja2                             3.1.6
# jmespath                           1.0.1
# joblib                             1.5.3
# jpholiday                          1.0.3
# json5                              0.13.0
# jsonpointer                        3.0.0
# jsonschema                         4.26.0
# jsonschema-specifications          2025.9.1
# jupyter                            1.1.1
# jupyter_client                     8.7.0
# jupyter-console                    6.6.3
# jupyter_core                       5.9.1
# jupyter-events                     0.12.0
# jupyter-lsp                        2.3.0
# jupyter_server                     2.17.0
# jupyter_server_terminals           0.5.3
# jupyterlab                         4.5.1
# jupyterlab_pygments                0.3.0
# jupyterlab_server                  2.28.0
# jupyterlab_widgets                 3.0.16
# kaleido                            0.2.1
# keras                              3.13.2
# kiwisolver                         1.4.9
# lag-llama                          0.1.0
# lark                               1.3.1
# lazy_loader                        0.4
# lib-inspector-v2                   0.1.0                        /mnt/e/env/ts/tslib/model/tool/db
# libclang                           18.1.1
# libcst                             1.8.6
# lightgbm                           4.6.0
# lightning                          2.6.0
# lightning-utilities                0.15.2
# linkify-it-py                      2.0.3
# llvmlite                           0.46.0
# local-attention                    1.4.4
# loguru                             0.7.3
# lxml                               6.0.2
# Mako                               1.3.10
# Markdown                           3.10.2
# markdown-it-py                     4.0.0
# MarkupSafe                         3.0.3
# matplotlib                         3.9.2
# matplotlib-inline                  0.2.1
# mdit-py-plugins                    0.5.0
# mdurl                              0.1.2
# mistune                            3.2.0
# mkl_fft                            2.1.1
# mkl_random                         1.3.0
# mkl-service                        2.5.2
# ml_dtypes                          0.5.4
# mlflow                             3.8.1
# mlflow-skinny                      3.8.1
# mlflow-tracing                     3.8.1
# mlforecast                         0.14.0
# model-index                        0.1.11
# momentchi2                         0.1.8
# mpld3                              0.5.12
# mpmath                             1.3.0
# msgpack                            1.1.2
# multidict                          6.7.0
# multiprocess                       0.70.16
# murmurhash                         1.0.15
# mutmut                             3.4.0
# mypy                               1.11.1
# mypy_extensions                    1.1.0
# namex                              0.1.0
# narwhals                           2.16.0
# nbclient                           0.10.4
# nbconvert                          7.16.6
# nbformat                           5.10.4
# ndindex                            1.10.1
# nest_asyncio                       1.6.0
# networkx                           3.6.1
# neuralforecast                     3.1.4
# neuralprophet                      0.9.0
# nf-app                             0.1.0                        /mnt/e/env/ts/loto/nf_app_pkg
# nfoursid                           1.0.2
# ninja                              1.13.0
# nixtla                             0.7.2
# nlpaug                             1.1.11
# nltk                               3.9.2
# notebook                           7.5.1
# notebook_shim                      0.2.4
# numba                              0.63.1
# numexpr                            2.14.1
# numpy                              2.4.2
# nvidia-cublas                      13.0.0.19
# nvidia-cublas-cu12                 12.1.3.1
# nvidia-cuda-cupti                  13.0.48
# nvidia-cuda-cupti-cu12             12.1.105
# nvidia-cuda-nvrtc                  13.0.48
# nvidia-cuda-nvrtc-cu12             12.1.105
# nvidia-cuda-runtime                13.0.48
# nvidia-cuda-runtime-cu12           12.1.105
# nvidia-cudnn-cu12                  9.1.0.70
# nvidia-cudnn-cu13                  9.13.0.50
# nvidia-cufft                       12.0.0.15
# nvidia-cufft-cu12                  11.0.2.54
# nvidia-cufile                      1.15.0.42
# nvidia-curand                      10.4.0.35
# nvidia-curand-cu12                 10.3.2.106
# nvidia-cusolver                    12.0.3.29
# nvidia-cusolver-cu12               11.4.5.107
# nvidia-cusparse                    12.6.2.49
# nvidia-cusparse-cu12               12.1.0.106
# nvidia-cusparselt-cu13             0.8.0
# nvidia-nccl-cu12                   2.20.5
# nvidia-nccl-cu13                   2.27.7
# nvidia-nvjitlink                   13.0.39
# nvidia-nvjitlink-cu12              12.9.86
# nvidia-nvshmem-cu13                3.3.24
# nvidia-nvtx                        13.0.39
# nvidia-nvtx-cu12                   12.1.105
# oauthlib                           3.3.1
# omegaconf                          2.3.0
# opencensus                         0.11.4
# opencensus-context                 0.1.3
# opendatalab                        0.0.10
# openmim                            0.3.9
# openpyxl                           3.1.5
# opentelemetry-api                  1.39.1
# opentelemetry-exporter-prometheus  0.60b1
# opentelemetry-proto                1.39.1
# opentelemetry-sdk                  1.39.1
# opentelemetry-semantic-conventions 0.60b1
# openxlab                           0.0.11
# opt_einsum                         3.4.0
# optree                             0.18.0
# optuna                             4.6.0
# ordered-set                        4.1.0
# orjson                             3.11.5
# overrides                          7.7.0
# packaging                          26.0
# pandas                             2.3.3
# pandera                            0.28.1
# pandocfilters                      1.5.1
# parso                              0.8.5
# pathspec                           1.0.3
# patool                             1.12
# patsy                              1.0.2
# pbr                                7.0.3
# pdf2image                          1.17.0
# peft                               0.4.0
# pexpect                            4.9.0
# pfzy                               0.3.4
# pillow                             12.1.1
# pip                                26.0.1
# platformdirs                       4.5.1
# plotly                             5.18.0
# plotly-resampler                   0.11.0
# pluggy                             1.6.0
# plum-dispatch                      2.6.1
# pmdarima                           2.0.4
# polars                             1.37.0
# polars-runtime-32                  1.37.0
# ppca                               0.0.4
# preshed                            3.0.12
# product_key_memory                 0.1.10
# prometheus_client                  0.23.1
# prompt_toolkit                     3.0.52
# propcache                          0.4.1
# prophet                            1.2.1
# proto-plus                         1.27.0
# protobuf                           6.33.5
# psutil                             7.1.3
# psycopg                            3.3.2
# psycopg-binary                     3.3.2
# psycopg2                           2.9.11
# psycopg2-binary                    2.9.11
# ptyprocess                         0.7.0
# pure_eval                          0.2.3
# py-cpuinfo                         9.0.0
# py-spy                             0.4.1
# py4j                               0.10.9.9
# pyaml                              25.7.0
# pyarrow                            22.0.0
# pyarrow-hotfix                     0.7
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.2
# pybind11                           3.0.1
# pycaret                            3.3.2
# pycatch22                          0.4.5
# pycparser                          2.22
# pycryptodome                       3.23.0
# pydantic                           2.12.5
# pydantic_core                      2.41.5
# pydeck                             0.9.1
# pydot                              4.0.1
# Pygments                           2.19.2
# pygrinder                          0.7
# pylatexenc                         2.10
# pynndescent                        0.6.0
# pyod                               2.0.6
# pyOpenSSL                          25.3.0
# pyparsing                          3.3.1
# pypots                             1.0
# PySocks                            1.7.1
# pytesseract                        0.3.13
# pytest                             9.0.2
# pytest-cov                         7.0.0
# pytest-env                         1.1.5
# pytest-html                        4.1.1
# pytest-metadata                    3.1.1
# python-dateutil                    2.9.0.post0
# python-dotenv                      1.0.0
# python-fasthtml                    0.12.39
# python-json-logger                 4.0.0
# python-multipart                   0.0.21
# pytorch-lightning                  2.1.4
# pytorch-metric-learning            2.8.1
# pyts                               0.13.0
# pytz                               2025.2
# pyu2f                              0.1.5
# PyWavelets                         1.9.0
# PyYAML                             6.0.3
# pyzmq                              27.1.0
# qpsolvers                          4.8.2
# ray                                2.52.1
# referencing                        0.37.0
# reformer-pytorch                   1.4.4
# regex                              2025.11.3
# requests                           2.32.5
# retrying                           1.4.2
# rfc3339-validator                  0.1.4
# rfc3986-validator                  0.1.1
# rfc3987-syntax                     1.1.0
# rich                               14.3.2
# roman-numerals                     4.1.0
# rotary-embedding-torch             0.8.6
# rpds-py                            0.30.0
# rsa                                4.9.1
# s3transfer                         0.10.4
# safetensors                        0.7.0
# salesforce-merlion                 2.0.4
# schemdraw                          0.15
# scikit-base                        0.7.8
# scikit-image                       0.25.2
# scikit-learn                       1.7.2
# scikit-optimize                    0.10.2
# scikit-plot                        0.3.7
# scikit-posthocs                    0.11.4
# scipy                              1.16.3
# seaborn                            0.13.2
# seglearn                           1.2.5
# Send2Trash                         2.0.0
# sentencepiece                      0.2.0
# sentry-sdk                         2.49.0
# seqeval                            1.2.2
# setproctitle                       1.2.2
# setuptools                         82.0.0
# sgmllib3k                          1.0.0
# shap                               0.42.1
# shellingham                        1.5.4
# simdkalman                         1.0.4
# six                                1.17.0
# skforecast                         0.18.0
# sklearn-compat                     0.1.5
# skpro                              2.10.0
# sktime                             0.16.1
# slicer                             0.0.7
# smart_open                         7.5.0
# smmap                              5.0.2
# snowballstemmer                    3.0.1
# sortedcontainers                   2.4.0
# soupsieve                          2.8.1
# spacy                              3.8.11
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# Sphinx                             9.0.4
# sphinx-autodoc-typehints           3.6.1
# sphinx-rtd-theme                   0.5.1
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.46
# SQLAlchemy-Utils                   0.42.1
# sqlparse                           0.5.5
# srsly                              2.5.2
# stack_data                         0.6.3
# stanio                             0.5.1
# starlette                          0.50.0
# statsforecast                      2.0.3
# statsmodels                        0.14.6
# stevedore                          5.4.1
# streamlit                          1.54.0
# stumpy                             1.13.0
# svgwrite                           1.4.3
# sympy                              1.14.0
# tables                             3.10.2
# tabulate                           0.9.0
# tb-nightly                         2.21.0a20251023
# tbats                              1.1.3
# temporian                          0.9.0
# tenacity                           9.1.4
# tensorboard                        2.20.0
# tensorboard-data-server            0.7.2
# tensorboardX                       2.6.4
# tensordict                         0.6.2
# tensorflow                         2.20.0
# tensorflow-io-gcs-filesystem       0.37.1
# termcolor                          3.3.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textual                            7.3.0
# thinc                              8.3.10
# threadpoolctl                      3.6.0
# tifffile                           2025.12.20
# timesfm                            2.0.0
# timm                               1.0.3
# tinycss2                           1.4.0
# tirex-ts                           1.3.0
# tokenizers                         0.22.2
# toml                               0.10.2
# tomli                              2.4.0
# toolz                              0.12.1
# torch                              2.4.1
# torchdata                          0.11.0
# torchmetrics                       1.7.4
# torchvision                        0.24.1+cu130
# tornado                            6.5.4
# toto-ts                            0.1.4                        /mnt/e/env/ts/tslib/model/toto
# tqdm                               4.67.1
# traitlets                          5.14.3
# transformers                       4.56.0
# Tree                               0.2.4
# triad                              1.0.0
# triton                             3.0.0                  1
# tsa                                0.1.0                        /mnt/e/env/ts/tslib/model/time-series-autoencoder
# tsdb                               0.7.1
# tsdownsample                       0.1.4.1
# tsflex                             0.4.1
# tsfresh                            0.21.1
# tslearn                            0.7.0
# typeguard                          2.13.3
# typer                              0.21.1
# typer-slim                         0.21.1
# types-PyYAML                       6.0.12.20240917
# types-tabulate                     0.9.0.20241207
# typing_extensions                  4.15.0
# typing-inspect                     0.9.0
# typing-inspection                  0.4.2
# tzdata                             2025.3
# uc-micro-py                        1.0.3
# umap-learn                         0.5.9.post2
# uni2ts                             2.0.0                        /mnt/e/env/ts/tslib/model/uni2ts
# uri-template                       1.3.0
# urllib3                            2.6.3
# utilsforecast                      0.2.15
# uv                                 0.9.21
# uvicorn                            0.40.0
# uvloop                             0.22.1
# verl                               0.2.0.dev0
# virtualenv                         20.36.1
# wadler_lindig                      0.1.7
# waitress                           3.0.2
# wandb                              0.23.1
# wasabi                             1.1.3
# watchdog                           6.0.0
# watchfiles                         1.1.1
# wcwidth                            0.2.14
# weasel                             0.4.3
# webcolors                          25.10.0
# webencodings                       0.5.1
# websocket-client                   1.9.0
# websockets                         16.0
# Werkzeug                           3.1.5
# wheel                              0.46.3
# widgetsnbextension                 4.0.15
# window_ops                         0.0.15
# wrapt                              2.1.1
# wurlitzer                          3.1.1
# xarray                             2025.6.1
# xformers                           0.0.30
# xgboost                            3.1.3
# xlrd                               2.0.2
# xxhash                             3.6.0
# yarl                               1.22.0
# yellowbrick                        1.5
# zipp                               3.23.0
# zstandard                          0.25.0

# %% [markdown]
# ## データの前処理 (TimesFM入力形式への変換)

# %%
# 時系列データをモデル入力用に整形
# TimesFM は List[np.ndarray] 形式の入力を期待します

# ユニークIDの作成（管理用）
df['unique_id'] = df['loto'] + "_" + df['ts_type']

# グルーピングしてリスト化
grouped = df.groupby('unique_id')

input_ts_list = []
metadata_list = []

for name, group in grouped:
    # yカラムをnumpy配列として抽出
    # float32型に変換しておくと無難です
    y_values = group['y'].values.astype(np.float32)
    
    # データが空でないか確認
    if len(y_values) > 0:
        input_ts_list.append(y_values)
        metadata_list.append({
            "unique_id": name,
            "loto": group['loto'].iloc[0],
            "ts_type": group['ts_type'].iloc[0],
            "last_ds": group['ds'].iloc[-1]
        })

print(f"Prepared {len(input_ts_list)} time series for forecasting.")
# サンプルとして最初の系列の長さを表示
if input_ts_list:
    print(f"Sample 0 length: {len(input_ts_list[0])}")
# Out:
# Prepared 36 time series for forecasting.
# Sample 0 length: 3648

# %% [markdown]
# ## モデルのロードとコンパイル

# %%
# モデルの初期化 (PyTorch 200M版)
# 初回実行時はHugging Face Hubからモデルをダウンロードします
try:
    print("Loading TimesFM model...")
    model = timesfm.TimesFM_2p5_200M_torch.from_pretrained(
        "google/timesfm-2.5-200m-pytorch",
        torch_compile=True  # 高速化のためTrue推奨 (Linux環境等)
    )
    
    # 予測設定のコンパイル
    # データセットの長さや予測したい期間に合わせてパラメータを調整してください
    PRED_LEN = 12  # 予測期間（ホライズン）
    CONTEXT_LEN = 512 # 入力コンテキスト長（データの長さに応じて調整）

    model.compile(
        timesfm.ForecastConfig(
            max_context=CONTEXT_LEN,
            max_horizon=PRED_LEN,
            normalize_inputs=True, # 入力データの正規化を行う
            use_continuous_quantile_head=True,
            force_flip_invariance=True,
            infer_is_positive=False, # データが負の値を取りうる場合はFalse
            fix_quantile_crossing=True,
        )
    )
    print("Model loaded and compiled successfully.")

except Exception as e:
    print(f"Error loading model: {e}")
    # 代替案: torch_compile=False で再試行
    if "compile" in str(e):
         print("Retrying without torch_compile...")
         model = timesfm.TimesFM_2p5_200M_torch.from_pretrained(
            "google/timesfm-2.5-200m-pytorch",
            torch_compile=False
        )
# Out:
# Loading TimesFM model...
# config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# Downloaded.
# /home/az/miniconda3/envs/ts/lib/python3.11/site-packages/torch/cuda/__init__.py:230: UserWarning:
# NVIDIA GeForce RTX 5070 Ti with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5070 Ti GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
# Compiling model...
# Model loaded and compiled successfully.

# %% [markdown]
# ## Model Loading

# %%
import sys
import os
import torch

# ステップ1で特定したパスをここにハードコードしておくと次回から楽です
# 例: SRC_PATH = "/mnt/e/env/ts/lib_ana/timesfm/src"
# if SRC_PATH not in sys.path: sys.path.insert(0, SRC_PATH)

from timesfm.timesfm_2p5.timesfm_2p5_torch import TimesFM_2p5_200M_torch
import timesfm

print("Loading TimesFM model...")
try:
    # モデルのロード
    model = TimesFM_2p5_200M_torch.from_pretrained(
        "google/timesfm-2.5-200m-pytorch",
        torch_compile=True
    )
    
    # コンパイル設定
    model.compile(
        timesfm.ForecastConfig(
            max_context=512,
            max_horizon=12,
            normalize_inputs=True,
            use_continuous_quantile_head=True,
            force_flip_invariance=True,
            infer_is_positive=False,
            fix_quantile_crossing=True,
        )
    )
    print("Model ready.")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# Loading TimesFM model...
# config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# Downloaded.
# Compiling model...
# Model ready.
# /home/az/miniconda3/envs/ts/lib/python3.11/site-packages/torch/cuda/__init__.py:230: UserWarning:
# NVIDIA GeForce RTX 5070 Ti with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_70 sm_75 sm_80 sm_86 sm_90.
# If you want to use the NVIDIA GeForce RTX 5070 Ti GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
import os, sys, importlib

print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])

import timesfm
print("imported timesfm from:", timesfm.__file__)
# Out:
# cwd: /mnt/e/env/ts/lib_ana
# sys.path[0]: /home/az/miniconda3/envs/ts/lib/python311.zip
# imported timesfm from: /home/az/miniconda3/envs/ts/lib/python3.11/site-packages/timesfm/__init__.py

# %% [markdown]
# ## ファイル作成＆実行（フルパス）

# %%
from pathlib import Path

ANALYZER_PATH = Path("/mnt/e/env/ts/lib_ana/src/model/timesfm/_analysis/param_analyzer.py")
ANALYZER_PATH.parent.mkdir(parents=True, exist_ok=True)

# 上のフルコードを、ここにそのまま貼って書き出してもOK。
# 既に作成済みなら不要。
print("Analyzer path:", str(ANALYZER_PATH))
# Out:
# Analyzer path: /mnt/e/env/ts/lib_ana/src/model/timesfm/_analysis/param_analyzer.py

# %% [markdown]
# ## 1. TimesFM モデルの初期化とロード
# 事前学習済みのTimesFMモデル (2.5 200M) をロードします。PyTorchバックエンドを使用し、チェックポイントを指定して初期化します。

# %%
import torch
from timesfm import TimesFM_2p5_200M_torch

# GPUが利用可能か確認
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# モデルの読み込み
# huggingfaceのリポジトリIDまたはローカルパスを指定
# backend: 'torch' (または 'flax')
tfm = TimesFM_2p5_200M_torch.from_pretrained(
    model_id="google/timesfm-2.5-200m-pytorch",
    device_map=device,
    # 必要に応じてローカルキャッシュやトークンを指定可能
    # cache_dir=None,
    # force_download=False,
    # token=None
)

print("Model loaded successfully.")
# Out:
# Using device: cuda
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       6 print(f"Using device: {device}")
#       8 # モデルの読み込み
#       9 # huggingfaceのリポジトリIDまたはローカルパスを指定
#      10 # backend: 'torch' (または 'flax')
# ---> 11 tfm = TimesFM_2p5_200M_torch.from_pretrained(
#      12     model_id="google/timesfm-2.5-200m-pytorch",
#      13     device_map=device,
#      14     # 必要に応じてローカルキャッシュやトークンを指定可能
#      15     # cache_dir=None,
#      16     # force_download=False,
#      17     # token=None
#      18 )
#      20 print("Model loaded successfully.")
#
# File ~/miniconda3/envs/ts/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# TypeError: ModelHubMixin.from_pretrained() missing 1 required positional argument: 'pretrained_model_name_or_path'

# %% [markdown]
# ## 2. 予測設定 (ForecastConfig) の定義
# 推論時の最大コンテキスト長、最大ホライズン、入力の正規化など、予測に関する詳細なパラメータを設定します。ここでは可能な限りすべての引数を明示します。

# %%
from timesfm.configs import ForecastConfig

# 予測設定の作成
forecast_config = ForecastConfig(
    max_context=512,       # モデルに入力する最大過去データ点数 (最大2048まで)
    max_horizon=96,        # 一度に予測する最大ステップ数
    normalize_inputs=True, # 入力を正規化するかどうか (推奨: True)
    per_core_batch_size=32,# バッチサイズ
    
    # 以下は高度な設定 (デフォルト値を明示)
    window_size=None,                  # 特定のウィンドウサイズが必要な場合指定
    use_continuous_quantile_head=False,# 連続分位点ヘッドの使用有無
    force_flip_invariance=False,       # 反転不変性を強制するか (aX+b の処理)
    infer_is_positive=False,           # 出力が非負であることを保証するか
    fix_quantile_crossing=True,        # 分位点の交差を修正するか
    return_backcast=False              # 過去データの再構成(backcast)を返すか
)

print("ForecastConfig configured.")
# Out:
# ForecastConfig configured.

# %% [markdown]
# ## 3. モデルのコンパイル (Compile)
# 作成した `forecast_config` をモデルに適用し、推論グラフをコンパイルします。これにより推論が最適化されます。

# %%
# モデルのコンパイル
# backend='torch' の場合、torch.compileなどが内部で呼ばれる可能性があります（実装依存）
tfm.compile(
    forecast_config=forecast_config,
    # 追加のkwargsがある場合ここに渡す
)

print("Model compiled.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # モデルのコンパイル
#       2 # backend='torch' の場合、torch.compileなどが内部で呼ばれる可能性があります（実装依存）
# ----> 3 tfm.compile(
#       4     forecast_config=forecast_config,
#       5     # 追加のkwargsがある場合ここに渡す
#       6 )
#       8 print("Model compiled.")
#
# NameError: name 'tfm' is not defined

# %% [markdown]
# ## 4. 時系列予測の実行 (Forecast)
# 準備した `input_ts_list` (List[np.ndarray]) を使用して予測を実行します。

# %%
import numpy as np

# 予測したい期間（ホライズン）を指定
horizon_len = 96 

# 予測の実行
# input_ts_list はユーザーコードで作成済みの List[np.ndarray] を想定
point_forecast, experimental_quantile_forecast = tfm.forecast(
    inputs=input_ts_list,
    horizon=horizon_len
)

# 結果の確認
print(f"Point Forecast Shape: {point_forecast.shape}")
# (Batch_Size, Horizon)

if experimental_quantile_forecast is not None:
    print(f"Quantile Forecast Shape: {experimental_quantile_forecast.shape}")
    # (Batch_Size, Horizon, Quantiles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       4 horizon_len = 96
#       6 # 予測の実行
#       7 # input_ts_list はユーザーコードで作成済みの List[np.ndarray] を想定
# ----> 8 point_forecast, experimental_quantile_forecast = tfm.forecast(
#       9     inputs=input_ts_list,
#      10     horizon=horizon_len
#      11 )
#      13 # 結果の確認
#      14 print(f"Point Forecast Shape: {point_forecast.shape}")
#
# NameError: name 'tfm' is not defined

# %% [markdown]
# ## 5. 外部共変量を使用した予測 (Forecast with Covariates)
# `forecast_with_covariates` メソッドを使用して、動的・静的な共変量を加味した予測を行います。引数をすべて使用するため、ダミーの共変量データを作成して渡します。

# %%
# --- 共変量データのダミー作成 (引数全使用のため) ---
# 実際のデータがある場合はそれを使用してください

num_series = len(input_ts_list)
# 各系列の入力長を取得
input_lens = [len(x) for x in input_ts_list]

# 1. 動的数値共変量 (Dynamic Numerical): 例 [気温, 湿度]
# train側: 入力系列と同じ長さである必要があります
train_dyn_num = {
    "temp": [np.random.randn(l).tolist() for l in input_lens],
    "humid": [np.random.randn(l).tolist() for l in input_lens]
}
# test側: 予測期間 (horizon_len) と同じ長さである必要があります
test_dyn_num = {
    "temp": [np.random.randn(horizon_len).tolist() for _ in range(num_series)],
    "humid": [np.random.randn(horizon_len).tolist() for _ in range(num_series)]
}

# 2. 動的カテゴリ共変量 (Dynamic Categorical): 例 [曜日, 祝日]
# 注: TimesFM自体は数値入力を期待するため、カテゴリは数値エンコードされているか、
# 内部のxreg_libが処理できる形式である必要があります。ここではリスト形式で渡します。
train_dyn_cat = {
    "dow": [np.random.randint(0, 7, l).tolist() for l in input_lens]
}
test_dyn_cat = {
    "dow": [np.random.randint(0, 7, horizon_len).tolist() for _ in range(num_series)]
}

# 3. 静的数値共変量 (Static Numerical): 例 [店舗面積]
# 各系列につき1つの値
static_num = {
    "area": [np.random.rand() for _ in range(num_series)]
}

# 4. 静的カテゴリ共変量 (Static Categorical): 例 [店舗タイプ]
# 各系列につき1つの値
static_cat = {
    "store_type": [np.random.randint(0, 3) for _ in range(num_series)]
}

# --- 共変量付き予測の実行 ---

cov_point_forecast, cov_xreg_out = tfm.forecast_with_covariates(
    inputs=input_ts_list,
    
    # 動的共変量 (学習期間/コンテキスト)
    dynamic_numerical_covariates={**train_dyn_num}, # train_dynamic_numerical_covariatesに相当
    dynamic_categorical_covariates={**train_dyn_cat},
    
    # 注意: forecast_with_covariatesの実装では、
    # trainとtestの共変量を辞書内で結合して渡すか、内部ロジックに従う必要があります。
    # ライブラリの仕様上、forecast_with_covariatesの引数は以下の通りです:
    # dynamic_numerical_covariates, dynamic_categorical_covariates, 
    # static_numerical_covariates, static_categorical_covariates
    # これらは通常、辞書内で 'train' 部分と 'test' 部分を持つか、
    # ライブラリによってはここですべて渡すと内部で分割、あるいは
    # 呼び出し側で結合して渡すことが求められます。
    # TimesFMのxreg_libの仕様に合わせ、ここでは全ての引数を明示します。
    
    # *実際の実装(timesfm_2p5_base.py)を確認すると引数は以下の通りです*
    # inputs, dynamic_numerical_covariates, dynamic_categorical_covariates,
    # static_numerical_covariates, static_categorical_covariates, ...
    # 辞書の値は Sequence[Sequence[float]] なので、
    # ここでは「コンテキスト + ホライズン」の結合データを渡すのが一般的ですが、
    # 多くの実装ではコンテキスト部分のみ、あるいはAPI仕様によります。
    # ここではAPI定義通り辞書を渡します。
    
    static_numerical_covariates=static_num,
    static_categorical_covariates=static_cat,
    
    # 設定パラメータ
    xreg_mode="xreg + timesfm",  # "xreg + timesfm" (残差予測) or "timesfm + xreg"
    normalize_xreg_target_per_input=True, # 入力ごとにターゲットを正規化するか
    ridge=0.0,                   # リッジ回帰の正則化パラメータ
    max_rows_per_col=0,          # 線形モデル用サブサンプリング (0は無効)
    force_on_cpu=False           # 線形モデル計算をCPUに強制するか
)

print(f"Covariate Forecast Shape: {cov_point_forecast.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 44
#      38 static_cat = {
#      39     "store_type": [np.random.randint(0, 3) for _ in range(num_series)]
#      40 }
#      42 # --- 共変量付き予測の実行 ---
# ---> 44 cov_point_forecast, cov_xreg_out = tfm.forecast_with_covariates(
#      45     inputs=input_ts_list,
#      46
#      47     # 動的共変量 (学習期間/コンテキスト)
#      48     dynamic_numerical_covariates={**train_dyn_num}, # train_dynamic_numerical_covariatesに相当
#      49     dynamic_categorical_covariates={**train_dyn_cat},
#      50
#      51     # 注意: forecast_with_covariatesの実装では、
#      52     # trainとtestの共変量を辞書内で結合して渡すか、内部ロジックに従う必要があります。
#      53     # ライブラリの仕様上、forecast_with_covariatesの引数は以下の通りです:
#      54     # dynamic_numerical_covariates, dynamic_categorical_covariates,
#      55     # static_numerical_covariates, static_categorical_covariates
#      56     # これらは通常、辞書内で 'train' 部分と 'test' 部分を持つか、
#      57     # ライブラリによってはここですべて渡すと内部で分割、あるいは
#      58     # 呼び出し側で結合して渡すことが求められます。
#      59     # TimesFMのxreg_libの仕様に合わせ、ここでは全ての引数を明示します。
#      60
#      61     # *実際の実装(timesfm_2p5_base.py)を確認すると引数は以下の通りです*
#      62     # inputs, dynamic_numerical_covariates, dynamic_categorical_covariates,
#      63     # static_numerical_covariates, static_categorical_covariates, ...
#      64     # 辞書の値は Sequence[Sequence[float]] なので、
#      65     # ここでは「コンテキスト + ホライズン」の結合データを渡すのが一般的ですが、
#      66     # 多くの実装ではコンテキスト部分のみ、あるいはAPI仕様によります。
#      67     # ここではAPI定義通り辞書を渡します。
#      68
#      69     static_numerical_covariates=static_num,
#      70     static_categorical_covariates=static_cat,
#      71
#      72     # 設定パラメータ
#      73     xreg_mode="xreg + timesfm",  # "xreg + timesfm" (残差予測) or "timesfm + xreg"
#      74     normalize_xreg_target_per_input=True, # 入力ごとにターゲットを正規化するか
#      75     ridge=0.0,                   # リッジ回帰の正則化パラメータ
#      76     max_rows_per_col=0,          # 線形モデル用サブサンプリング (0は無効)
#      77     force_on_cpu=False           # 線形モデル計算をCPUに強制するか
#      78 )
#      80 print(f"Covariate Forecast Shape: {cov_point_forecast.shape}")
#
# NameError: name 'tfm' is not defined

# %%
# Auto-generated call stub (CLE V6)

# NOTE: TODO のところを埋めてください

from timesfm.configs import ForecastConfig

obj = ForecastConfig(
    max_context=0,
    max_horizon=0,
    normalize_inputs=False,
    window_size=0,
    per_core_batch_size=1,
    use_continuous_quantile_head=False,
    force_flip_invariance=True,
    infer_is_positive=True,
    fix_quantile_crossing=False,
    return_backcast=False,
)

# %%
obj
# Out:
# ForecastConfig(max_context=0, max_horizon=0, normalize_inputs=False, window_size=0, per_core_batch_size=1, use_continuous_quantile_head=False, force_flip_invariance=True, infer_is_positive=True, fix_quantile_crossing=False, return_backcast=False)
