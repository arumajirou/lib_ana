# %%
import os, sys, subprocess

os.chdir(r"C:\lib_ana\src")
subprocess.run([sys.executable, "-m", "streamlit", "run", r"v6\streamlit_app\app.py"], check=False)

# %%
cd C:\lib_ana\src
streamlit cache clear
streamlit run v6\streamlit_app\app.py
# Out:
#   Cell In[1], line 1
#     cd C:\lib_ana\src
#        ^
# SyntaxError: invalid syntax

# %%
import os, sys, subprocess
os.chdir(r"C:\lib_ana\src")
subprocess.run([sys.executable, "-m", "streamlit", "cache", "clear"], check=False)
subprocess.run([sys.executable, "-m", "streamlit", "run", r"v6\streamlit_app\app.py"], check=False)

# %%
# 例：Downloadsにある前提
Expand-Archive -Force "C:\lib_ana\CLE_V6_streamlit_pkg_enhanced_v3.zip" "C:\lib_ana"
